# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
description = []
price = []
no_ratings = []
offer = []

# %%
pages = list(range(1,2))
for page in pages:
    url = requests.get("https://www.nykaa.com/makeup/eyes/eyeliner/c/240?page_no={}&sort=popularity&eq=desktop".format(page)).text
    print(url)
#     soup = BeautifulSoup(url,"html.parser")
#     print(soup)
    
#     # description
#     desc = soup.find_all("div", class_="css-xrzmfa")
#     for i in range (0,len(desc)):
#         description.append(desc[i].text)
    
#     # price
#     pri = soup.find_all("span", class_="css-111z9ua")
#     for i in range (0,len(pri)):
#         price.append(pri[i].text)
     
#     # no_ratings
#     rat  = soup.find_all("span", class_="css-1j33oxj")
#     for i in range (0,len(rat)):
#         no_ratings.append(rat[i].text)
        
#     # offer
#     off  = soup.find_all(color="0", class_="css-i6xqbh")
#     for i in range (0,len(off)):
#         offer.append(off[i].text)
# Out:
# <!doctype html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=5.0"/><meta name="theme-color" content="#fff"/><meta name="author" content="NykaaFrontendTeam"/><link rel="icon" href="//images-static.nykaa.com/media/favicon/default/nykaa_favicon_a.png" type="image/x-icon"/><link rel="canonical" href="https://www.nykaa.com/makeup/eyes/eyeliner/c/240"/><title data-react-helmet="true">Discount on Eyeliner - Buy Eyeliner Online in India at Best Price| Nykaa Hot Pink Sale 2022 | Nykaa</title><meta data-react-helmet="true" name="description" content="Eyeliner Online Offers: Buy the best eyeliner pen on sale at low price from Nykaa. Our top notch eyeliner pen selection includes glitter &amp; gel eyeliner, brown &amp; blue colored eyeliner and more from the finest brands. Check out the amazing Eyeliner offers now!"/><meta data-react-helmet="true" name="keywords" content="Buy eyeliner online,  buy eye liners in india
# ...

# %%
soup = BeautifulSoup(url,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(len(description))
print(len(price))
print(len(no_ratings))
print(len(offer))
# Out:
# 744
# 744
# 675
# 316

# %%
data = {"Description":description[slice(316)],"Price":price[slice(316)],"Number of Ratings":no_ratings[slice(316)],
        "Offer":offer[slice(316)]}
naykaa = pd.DataFrame(data)
naykaa
# Out:
#                                            Description  Price  \
# 0    Maybelline New York Line Tattoo High Impact Li...   ₹358
# 1                             Lakme Wink and Win Combo   ₹420
# 2    Nykaa Black Magic Liquid Eyeliner - Super Blac...   ₹254
# 3                  Colorbar Waterproof Liquid Eyeliner   ₹298
# 4    Kay Beauty Bedazzle Away Combo - Gel Eye Penci...  ₹1078
# ..                                                 ...    ...
# 311                       Smashbox Always On Gel Liner  ₹1520
# 312         PIXI Eye Define Waterline - TightlineBlack  ₹1320
# 313            Smashbox Always On Liquid Liner - Black  ₹1840
# 314  Benefit Cosmetics Roller Liner Black Liquid Ey...  ₹2190
# 315  Katrina's Natural Day Look - Kay Beauty Matte ...   ₹974
#
#     Number of Ratings             Offer
# 0            ( 2109 )   Enjoy Free Gift
# 1            ( 8368 )   Enjoy Free Gift
# 2           ( 14473 )  Get Free Product
# 3            ( 6198 )   Enjoy Free Gift
# ...

# %%
naykaa.to_csv("eye_liner_nykaa.csv")
